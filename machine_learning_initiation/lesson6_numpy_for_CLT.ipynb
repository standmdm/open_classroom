# %% [markdown]
# ## Le théorème central limite
# Etablit la convergence en loi de la somme d'une suite de variables aléatoires vers la loi normale avec une distribution gaussienne

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from math import exp, sqrt, pi

# %%
domaine = range(-100, 100)
# moyenne de la distribution
mu = 0
# Ecart type
sigma = 20

f = lambda x: 1/(sqrt(2 * pi * pow(sigma, 2))) * exp(-pow((x-mu), 2) / (2 * pow(sigma, 2)))

y = [f(x) for x in domaine]

plot =(plt.plot(domaine, y))

# %%
vecteur_aleatoire = np.random.rand(30)

# %%
plt.scatter(range(30), vecteur_aleatoire)
plt.plot()
# Out:
# []

# %%
matrice_aleatoire = np.random.rand(3,5)
matrice_aleatoire
# Out:
# array([[0.08747071, 0.94535075, 0.82342653, 0.98276123, 0.99920066],
#        [0.39073117, 0.52910724, 0.18621118, 0.28124825, 0.83223684],
#        [0.41687808, 0.94837274, 0.4672859 , 0.47077958, 0.43574211]])

# %%
matrice = np.random.rand(100,200)

# %%
np.sum(matrice)
# Out:
# 10021.271848692637

# %%
somme = np.sum(matrice,axis= 0)

# %%
somme.shape
# Out:
# (200,)

# %%
plt.scatter(range(200), somme)

# %%
plt.hist(somme)
# Out:
# (array([ 2.,  6., 15., 24., 47., 49., 24., 17., 13.,  3.]),
#  array([41.47252393, 43.14941807, 44.8263122 , 46.50320634, 48.18010048,
#         49.85699461, 51.53388875, 53.21078289, 54.88767702, 56.56457116,
#         58.2414653 ]),
#  <a list of 10 Patch objects>)

# %%
matrice = np.random.rand(1000,10000)

# %%
somme = np.sum(matrice, 0)

# %%
somme.shape
# Out:
# (10000,)

# %%
plot = plt.hist(somme, bins = 100)

# %%
print("La moyenne empirique de notre distribution est {}."
      .format(np.mean(somme)))
print("La moyenne empirique de la variable généré par la fonction rand est {}."
      .format(np.mean(np.random.rand(100000))))
print("La variance empirique de notre distribution est {}."
      .format(np.var(somme)))
print("La variance empirique de la variable généré par la fonction rand est {}."
      .format(np.var(np.random.rand(100000))))
# Out:
# La moyenne empirique de notre distribution est 500.0778859575745.
# La moyenne empirique de la variable généré par la fonction rand est 0.4998137641177162.
# La variance empirique de notre distribution est 83.68631715434915.
# La variance empirique de la variable généré par la fonction rand est 0.08301948112654521.
